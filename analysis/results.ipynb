# %% [markdown]
# # Results
# This file is a notebook meant to perform some statistical analysis on the csv reports from the `verification.py` script. Performing the data analysis on a separate notebook allows me to:
#   * decouple data creation from analysis
#   * having a persistent storage for plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('../out.csv')
data
# Out:
#         algorithm            name        backend      device       dtype  \
# 0    Algorithm.RS              rs  Backend.NUMPY  Device.CPU  DType.fp64
# 1    Algorithm.RS   rs_no_complex  Backend.NUMPY  Device.CPU  DType.fp64
# 2    Algorithm.RS  rs_manual_loop  Backend.NUMPY  Device.CPU  DType.fp64
# 3    Algorithm.RS              rs    Backend.JAX  Device.CPU  DType.fp64
# 4    Algorithm.RS   rs_no_complex    Backend.JAX  Device.CPU  DType.fp64
# ..            ...             ...            ...         ...         ...
# 795  Algorithm.RS              rs    Backend.JAX  Device.CPU  DType.fp64
# 796  Algorithm.RS   rs_no_complex    Backend.JAX  Device.CPU  DType.fp64
# 797  Algorithm.RS         rs_vmap    Backend.JAX  Device.CPU  DType.fp64
# 798  Algorithm.RS              rs  Backend.TORCH  Device.CPU  DType.fp64
# 799  Algorithm.RS   rs_no_complex  Backend.TORCH  Device.CPU  DType.fp64
#
#                      key       abs_err  total_time
# ...

# %%
data.columns
# Out:
# Index(['algorithm', 'name', 'backend', 'device', 'dtype', 'key', 'abs_err',
#        'total_time'],
#       dtype='object')
